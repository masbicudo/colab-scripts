# %%
#@title Julia Installation
# ref: https://colab.research.google.com/notebooks/forms.ipynb
# ref: https://colab.research.google.com/github/ageron/julia_notebooks/blob/master/Julia_Colab_Notebook_Template.ipynb
# ref: https://colab.research.google.com/github/Dsantra92/Julia-on-Colab/blob/master/Julia_on_colab.ipynb
# ref: https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb
# src: https://github.com/masbicudo/colab-scripts
# src: https://colab.research.google.com/github/masbicudo/colab-scripts/blob/main/julia.ipynb
#= Begin Julia multi-line comment
%%shell
#@markdown Define install options, then press <kbd>shift</kbd>+<kbd>enter</kbd> on this cell to install.
Version="1.7.0-rc1" #@param ["1.6.2", "1.0.5", "1.7.0-rc1"] {type:"string", allow-input: true}
#@markdown <span><center><sup>Discover more Julia versions at the <a href="https://julialang.org/downloads/" target="_blank">official download page</a> and then type the version number above.
Packages="" #@param ["DataFrames", "DifferentialEquations", "Flux", "Gadfly", "Gen", "Genie", "JuMP", "Knet", "MLJ", "Makie", "Mocha", "Plots", "Pluto", "PyCall", "Turing", "Zygote", "AdaGram", "Agents", "AlphaZero", "ApplicationBuilder", "ApproxFun", "ArgParse", "ArrayFire", "AutoGrad", "AutoMLPipeline", "BayesNets", "BenchmarkTools", "BinaryBuilder", "Bio", "BlackBoxOptim", "Blink", "BrainFlow", "Brochure", "BuildExecutable", "COSMO", "CSV", "CUDA", "CUDAnative", "Calculus", "Cassette", "Catalyst", "Catlab", "Celeste", "ChainRules", "Clang", "ClimateMachine", "ClusterManagers", "Clustering", "Compose", "ControlSystems", "Convex", "Cthulhu", "CuArrays", "CxxWrap", "Cxx", "DFTK", "DSGE", "DSP", "Dagger", "Dash-bootstrap-components", "Dash-core-components", "Dash-html-components", "Dash-table", "Dash", "DataDrivenDiffEq", "DataFramesMeta", "DataStructures", "Debugger", "Decentralized-Internet", "DecisionTree", "DiffEqBiological", "DiffEqFlux", "DiffEqOperators", "DiffEqTutorials", "Distances", "DistributedArrays", "Distributions", "Documenter", "DrWatson", "DynamicHMC", "DynamicalSystems", "Escher", "Evolutionary", "FDM", "FFTW", "FastAI", "FastGaussQuadrature", "FastGauss", "FastTransforms", "FileIO", "ForwardDiff", "Franklin", "GLM", "GLVisualize", "GPUArrays", "GR", "GalacticOptim", "Gallium", "GaussianProcesses", "GeneticAlgorithms", "GeoStats", "GeometricFlux", "Graphs", "Grassmann", "Gridap", "Gtk", "HDF5", "HTTP", "HypothesisTests", "ITensors", "Interact", "Interpolations", "IntervalArithmetic", "IterativeSolvers", "JET", "JLD2", "JLD", "JSON", "Javis", "JuDoc", "JuliaDB", "JuliaFEM", "JuliaFormatter", "JuliaReport", "JuliaWebAPI", "JuliaZH", "LanguageServer", "Laplacians", "Latexify", "LazyArrays", "Lazy", "LightGraphs", "LinearMaps", "Lint", "LispSyntax", "Literate", "LoopVectorization", "LowRankModels", "LsqFit", "Luxor", "MATLAB", "MAT", "MCMCChains", "MLBase", "MLStyle", "MPI", "MXNet", "MacroTools", "Mamba", "Manifolds", "Match", "MathOptInterface", "MeasureTheory", "Measurements", "Merlin", "MeshCat", "Metalhead", "MixedModels", "ModelingToolkit", "Modia", "MonteCarloMeasurements", "MultivariateStats", "Mux", "NLopt", "NLsolve", "NearestNeighbors", "NeuralNetDiffEq", "NeuralPDE", "NeuralVerification", "NiLang", "Oceananigans", "OhMyREPL", "OnlineStats", "OpenCL", "OpticSim", "Optim", "OrdinaryDiffEq", "PGFPlotsX", "PGFPlots", "POMDPs", "PackageCompiler", "ParallelAccelerator", "Parameters", "Pkg3", "PkgTemplates", "Pkg", "PlotlyJS", "PlutoUI", "PlutoUI", "PowerModels", "PowerSystems", "PrettyTables", "ProfileView", "ProgressMeter", "PyPlot", "QML", "QuantEcon", "QuantumOptics", "Query", "RCall", "Reactive", "Rebugger", "Reduce", "Reinforce", "ReinforcementLearning", "ReverseDiff", "Revise", "RigidBodyDynamics", "RobotOS", "SQLite", "SatelliteToolbox", "SciMLTutorials", "ScikitLearn", "SnoopCompile", "Soss", "Spark", "SpecialFunctions", "Stan", "StatPlots", "StaticArrays", "StatisticalRethinking", "StatsBase", "StatsModels", "StatsPlots", "Stheno", "StochasticDiffEq", "StructArrays", "SymPy", "Symata", "SymbolicUtils", "Symbolics", "Tables", "TaylorSeries", "TensorFlow", "TensorOperations", "TextAnalysis", "ThinkJulia", "ThreadsX", "TimeSeries", "TimerOutputs", "Traceur", "TrajectoryOptimization", "Transducers", "Transformers", "Tullio", "UnicodePlots", "Unitful", "VegaLite", "Weave", "WebIO", "Winston", "XGBoost", "XLA", "XLSX", "Yao"]{type:"string", allow-input: true}
#@markdown <span><center><sup>Discover more packages at the <a href="https://julialang.org/packages/" target="_blank">official packages page</a> and type them separated by spaces.</center><br>
#@markdown After installation process finishes, refresh the page.
#@markdown <p align="right"><sup><a href="https://colab.research.google.com/github/masbicudo/colab-scripts/blob/main/julia.ipynb#scrollTo=JuliaInstall" target="_blank">Original template notebook</a> and <a href="https://github.com/masbicudo/colab-scripts" target="_blank">GitHub project</a> by <a href="https://www.masbicudo.com" target="_blank">MASBicudo</a>/<a href="https://github.com/masbicudo/colab-scripts/blob/main/LICENSE" target="_blank">Apache License</a></sup></p>
git clone --depth 1 https://github.com/masbicudo/colab-scripts.git
./colab-scripts/install-julia.sh $Version $Packages
# End Julia multi-line comment =#
